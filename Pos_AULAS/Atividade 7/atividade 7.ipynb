# %%
import pandas as pd

# %%
import numpy as np

# %%
data_df = pd.read_csv('C:/Python/Pos_AULAS/Atividade 7/vinhos.csv', delimiter=',')

# %%
data_df
# Out:
#       acidez_fixa  acidez_volatil  acido_citrico  \
# 0             8.9           0.745           0.18
# 1             7.5           0.520           0.42
# 2             8.3           0.300           0.49
# 3             7.8           0.910           0.07
# 4             7.2           0.340           0.32
# ...           ...             ...            ...
# 2995          6.6           0.310           0.07
# 2996          6.2           0.240           0.27
# 2997          5.1           0.350           0.26
# 2998          8.0           0.450           0.28
# 2999          7.4           0.105           0.34
#
#       concentracao_residual_acucar  cloretos  dioxido_de_enxofre_livre  \
# 0                              2.5     0.077                      15.0
# 1                              2.3     0.087                       8.0
# 2                              3.8     0.090                      11.0
# 3                              1.9     0.058                      22.0
# ...
